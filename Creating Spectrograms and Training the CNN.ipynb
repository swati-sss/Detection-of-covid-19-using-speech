# %% [markdown]
# # Using the relevant voice samples of the patient, I have extracted only the cough voice samples and generated their mel spectrograms using the library Librosa.

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import pandas as pd
def create_spectrogram(audio_file_path, output_folder, counter):
    try:
        valid_audio_extensions = ('.wav', '.mp3', '.flac')
        if not audio_file_path.lower().endswith(valid_audio_extensions):
            print(f"Skipping {audio_file_path} as it is not a valid audio file.")
            return
        y, sr = librosa.load(audio_file_path)
        spectrogram = librosa.feature.melspectrogram(y=y, sr=sr)
        log_spectrogram = librosa.power_to_db(spectrogram, ref=np.max)
        os.makedirs(output_folder, exist_ok=True)
        output_filename = f'file{counter}.png'
        output_path = os.path.join(output_folder, output_filename)
        plt.figure(figsize=(10, 6))
        librosa.display.specshow(log_spectrogram, x_axis='time', y_axis='mel')
        plt.colorbar(format='%+2.0f dB')
        plt.title('Mel Spectrogram')
        plt.savefig(output_path, bbox_inches='tight', pad_inches=0)
        plt.close()
        print(f"Saved spectrogram: {output_path}")
    except Exception as e:
        print(f"Error processing {audio_file_path}: {str(e)}")

root_folder = ''  
output_folder_root = 'spectrogram_images' 

csv_path = os.path.join(root_folder, 'filtered_data.csv')
df = pd.read_csv(csv_path)
id_to_status = {row['id']: row['test_status'] for index, row in df.iterrows()}

processed_samples = 0


final_data_folder = os.path.join(root_folder, 'final_data')
for numbered_folder in os.listdir(final_data_folder):
    numbered_folder_path = os.path.join(final_data_folder, numbered_folder)

    if not os.path.isdir(numbered_folder_path):
        continue

   
    for ID in os.listdir(numbered_folder_path):
        ID_folder_path = os.path.join(numbered_folder_path, ID)

        if not os.path.isdir(ID_folder_path):
            continue

        test_status = id_to_status.get(ID)
        if test_status is None:
            print(f"No test status found for ID: {ID} - skipping.")
            continue

        if test_status == 'p':
            output_folder = os.path.join(output_folder_root, 'positive')
        elif test_status == 'n':
            output_folder = os.path.join(output_folder_root, 'negative')
        else:
            print(f"Unknown test status '{test_status}' for ID '{ID}' - skipping.")
            continue

        
        for voice_sample_name in os.listdir(ID_folder_path):
            voice_sample_path = os.path.join(ID_folder_path, voice_sample_name)
    
            if "cough-shallow" in voice_sample_name or "cough-heavy" in voice_sample_name:
                processed_samples += 1
                create_spectrogram(voice_sample_path, output_folder=output_folder, counter=processed_samples)
            else:
                print(f"Skipping '{voice_sample_name}' as it does not match 'cough-shallow' or 'cough-heavy' criteria.")
# Out:
# Unknown test status 'na' for ID 'mhSZr2kQUUXpZowNrDHw9eoRiwx1' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1.png
# Saved spectrogram: spectrogram_images/positive/file2.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file3.png
# Saved spectrogram: spectrogram_images/positive/file4.png
# Unknown test status 'na' for ID 'PwGuQGYgkScdEbKOiJsg4tyOYTA2' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file5.png
# Saved spectrogram: spectrogram_images/positive/file6.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file7.png
# Saved spectrogram: spectrogram_images/positive/file8.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file9.png
# Saved spectrogram: spectrogram_images/positive/file10.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file11.png
# Saved spectrogram: spectrogram_images/positive/file12.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file13.png
# Saved spectrogram: spectrogram_images/positive/file14.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file15.png
# Saved spectrogram: spectrogram_images/positive/file16.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file17.png
# Saved spectrogram: spectrogram_images/positive/file18.png
# Unknown test status 'na' for ID 'DzSbdHq5VTZB8CaVDWSnSUai5mt2' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file19.png
# Saved spectrogram: spectrogram_images/positive/file20.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file21.png
# Saved spectrogram: spectrogram_images/positive/file22.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/negative/file23.png
# Saved spectrogram: spectrogram_images/negative/file24.png
# Unknown test status 'na' for ID 'rxcxucbvOkPayD5EmBl3RAAtp3C3' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/negative/file25.png
# Saved spectrogram: spectrogram_images/negative/file26.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file27.png
# Saved spectrogram: spectrogram_images/positive/file28.png
# Unknown test status 'na' for ID 'ojyH22z0DOScG2wYRTuXD7vEAhl1' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file29.png
# Saved spectrogram: spectrogram_images/positive/file30.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file31.png
# Saved spectrogram: spectrogram_images/positive/file32.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/negative/file33.png
# Saved spectrogram: spectrogram_images/negative/file34.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file35.png
# Saved spectrogram: spectrogram_images/positive/file36.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file37.png
# Saved spectrogram: spectrogram_images/positive/file38.png
# Unknown test status 'na' for ID 'JAbr5e5oaIQa6gXUPpQuC5O17eD2' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file39.png
# Saved spectrogram: spectrogram_images/positive/file40.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file41.png
# Saved spectrogram: spectrogram_images/positive/file42.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file43.png
# Saved spectrogram: spectrogram_images/positive/file44.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file45.png
# Saved spectrogram: spectrogram_images/positive/file46.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file47.png
# Saved spectrogram: spectrogram_images/positive/file48.png
# Unknown test status 'na' for ID 'R4RGUF6ibtcRmk3SpqUoOO5JtEW2' - skipping.
# Unknown test status 'na' for ID 'V8HUkcYumWd6DLYFlhxkZkXFiH83' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file49.png
# Saved spectrogram: spectrogram_images/positive/file50.png
# Unknown test status 'na' for ID 'fYVZ4nvbW3f5v7xlccDvVTkVTzf2' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file51.png
# Saved spectrogram: spectrogram_images/positive/file52.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file53.png
# Saved spectrogram: spectrogram_images/positive/file54.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file55.png
# Saved spectrogram: spectrogram_images/positive/file56.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file57.png
# Saved spectrogram: spectrogram_images/positive/file58.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/negative/file59.png
# Saved spectrogram: spectrogram_images/negative/file60.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file61.png
# Saved spectrogram: spectrogram_images/positive/file62.png
# Unknown test status 'na' for ID 'vCAQ3LQHyBO9KkAYOoHKiO7NbMN2' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file63.png
# Saved spectrogram: spectrogram_images/positive/file64.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file65.png
# Saved spectrogram: spectrogram_images/positive/file66.png
# Unknown test status 'na' for ID '6v0A4zK7UmaG47UWSWLJldoVnau1' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file67.png
# Saved spectrogram: spectrogram_images/positive/file68.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file69.png
# Saved spectrogram: spectrogram_images/positive/file70.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file71.png
# Saved spectrogram: spectrogram_images/positive/file72.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/negative/file73.png
# Saved spectrogram: spectrogram_images/negative/file74.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file75.png
# Saved spectrogram: spectrogram_images/positive/file76.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file77.png
# Saved spectrogram: spectrogram_images/positive/file78.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file79.png
# Saved spectrogram: spectrogram_images/positive/file80.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file81.png
# Saved spectrogram: spectrogram_images/positive/file82.png
# Unknown test status 'na' for ID 'q1ruQZhVbqZ8gE0QERQFBGeERY83' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file83.png
# Saved spectrogram: spectrogram_images/positive/file84.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/negative/file85.png
# Saved spectrogram: spectrogram_images/negative/file86.png
# Unknown test status 'na' for ID 'qvsKZQ2TP5Q1a6Xd1F4rNUbA3qF2' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file87.png
# Saved spectrogram: spectrogram_images/positive/file88.png
# Unknown test status 'na' for ID 'Dz91gFv2ulfOIQ5docxFItx6jUF2' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file89.png
# Saved spectrogram: spectrogram_images/positive/file90.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file91.png
# Saved spectrogram: spectrogram_images/positive/file92.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file93.png
# Saved spectrogram: spectrogram_images/positive/file94.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file95.png
# Saved spectrogram: spectrogram_images/positive/file96.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file97.png
# Saved spectrogram: spectrogram_images/positive/file98.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/negative/file99.png
# Saved spectrogram: spectrogram_images/negative/file100.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file101.png
# Saved spectrogram: spectrogram_images/positive/file102.png
# Unknown test status 'na' for ID 'kE0LlnH8StYm0M8jUnKXlngtYyU2' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file103.png
# Saved spectrogram: spectrogram_images/positive/file104.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file105.png
# Saved spectrogram: spectrogram_images/positive/file106.png
# Unknown test status 'na' for ID 'mEb1cunNRZMy7gejeZerqvdfMfm1' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file107.png
# Saved spectrogram: spectrogram_images/positive/file108.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file109.png
# Saved spectrogram: spectrogram_images/positive/file110.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# ...
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1839.png
# Saved spectrogram: spectrogram_images/positive/file1840.png
# Unknown test status 'na' for ID 'g4IBjRbuXFXgkzAz1c6ORgGpHVg2' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1841.png
# Saved spectrogram: spectrogram_images/positive/file1842.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1843.png
# Saved spectrogram: spectrogram_images/positive/file1844.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1845.png
# Saved spectrogram: spectrogram_images/positive/file1846.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/negative/file1847.png
# Saved spectrogram: spectrogram_images/negative/file1848.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1849.png
# Saved spectrogram: spectrogram_images/positive/file1850.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1851.png
# Saved spectrogram: spectrogram_images/positive/file1852.png
# Unknown test status 'na' for ID '2DlLebpOzxaURwfwyo2fZiWIF1Z2' - skipping.
# Unknown test status 'na' for ID '356wSucV0OV6VQMvozjX63pIXrH2' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1853.png
# Saved spectrogram: spectrogram_images/positive/file1854.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/negative/file1855.png
# Saved spectrogram: spectrogram_images/negative/file1856.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1857.png
# Saved spectrogram: spectrogram_images/positive/file1858.png
# Unknown test status 'na' for ID 'mBWfpnNSpAe7cqXYcWhikoYA7SA2' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1859.png
# Saved spectrogram: spectrogram_images/positive/file1860.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1861.png
# Saved spectrogram: spectrogram_images/positive/file1862.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1863.png
# Saved spectrogram: spectrogram_images/positive/file1864.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1865.png
# Saved spectrogram: spectrogram_images/positive/file1866.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1867.png
# Saved spectrogram: spectrogram_images/positive/file1868.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1869.png
# Saved spectrogram: spectrogram_images/positive/file1870.png
# Unknown test status 'na' for ID 'KHP3hql1ScXYRbOQJ7anrZXTiad2' - skipping.
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1871.png
# Saved spectrogram: spectrogram_images/positive/file1872.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1873.png
# Saved spectrogram: spectrogram_images/positive/file1874.png
# Skipping 'counting-normal.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'metadata.json' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-o.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-a.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'vowel-e.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-shallow.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'counting-fast.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Skipping 'breathing-deep.wav' as it does not match 'cough-shallow' or 'cough-heavy' criteria.
# Saved spectrogram: spectrogram_images/positive/file1875.png
# Saved spectrogram: spectrogram_images/positive/file1876.png
# Unknown test status 'na' for ID 'WcRpZenx0WWQmzOUPTHEEGlyJAg1' - skipping.

# %% [markdown]
# # The total number of negative files were 515 and positive files were 1400+ so I augmented the Negative data

# %%
import Augmentor
input_dir = "spectrogram_images/negative"

output_dir = "spectrogram_images/negative"

num_images_to_generate = 800

p = Augmentor.Pipeline(input_dir, output_directory=output_dir)

p.rotate(probability=0.7, max_left_rotation=25, max_right_rotation=25)
p.flip_left_right(probability=0.5)
p.zoom_random(probability=0.5, percentage_area=0.8)
p.random_contrast(probability=0.5, min_factor=0.7, max_factor=1.3)

p.sample(num_images_to_generate)

print("Augmentation complete. Total images:", len(os.listdir(output_dir)))
# Out:
# Initialised with 514 image(s) found.
# Output directory set to spectrogram_images/negative/spectrogram_images/negative.
# Processing <PIL.Image.Image image mode=RGBA size=801x527 at 0x176C5A140>: 100%|█
# Augmentation complete. Total images: 515

# %% [markdown]
# # Now, Dividing the data in train test and validation sets which have two classes "Positive and "Negative":

# %%
import shutil
import random

root_dir = 'spectrogram_images'
classes = ['positive', 'negative']

train_ratio = 0.7
val_ratio = 0.2
test_ratio = 0.1

for cls in classes:
    os.makedirs(os.path.join(root_dir, 'train', cls), exist_ok=True)
    os.makedirs(os.path.join(root_dir, 'validation', cls), exist_ok=True)
    os.makedirs(os.path.join(root_dir, 'test', cls), exist_ok=True)

def split_data(cls):
    src_dir = os.path.join(root_dir, cls)
    all_files = [f for f in os.listdir(src_dir) if os.path.isfile(os.path.join(src_dir, f))]
    random.shuffle(all_files)
    
    train_files = all_files[:int(train_ratio*len(all_files))]
    val_files = all_files[int(train_ratio*len(all_files)):int((train_ratio+val_ratio)*len(all_files))]
    test_files = all_files[int((train_ratio+val_ratio)*len(all_files)):]

    for f in train_files:
        shutil.move(os.path.join(src_dir, f), os.path.join(root_dir, 'train', cls))
    for f in val_files:
        shutil.move(os.path.join(src_dir, f), os.path.join(root_dir, 'validation', cls))
    for f in test_files:
        shutil.move(os.path.join(src_dir, f), os.path.join(root_dir, 'test', cls))

for cls in classes:
    split_data(cls)

# %% [markdown]
# # Now, Training a CNN on Training set and validating it.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

train_dir = 'spectrogram_images/train' 
validation_dir = 'spectrogram_images/validation'  
test_dir = 'spectrogram_images/test'  


img_width, img_height = 150, 150
batch_size = 32


train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,  
    rotation_range=20, 
    width_shift_range=0.2, 
    height_shift_range=0.2,  
    horizontal_flip=True,  
    shear_range=0.2, 
    zoom_range=0.2, 
    fill_mode='nearest'  )

validation_datagen = ImageDataGenerator(rescale=1.0/255.0)
test_datagen = ImageDataGenerator(rescale=1.0/255.0)


train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary'
)


model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])


model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=50  
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary'
)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test accuracy: {test_acc}")

model.save('covid19_detection_model.h5')
# Out:
# Found 1312 images belonging to 2 classes.
# Found 375 images belonging to 2 classes.
# Epoch 1/50
# 41/41 [==============================] - 22s 520ms/step - loss: 0.7319 - accuracy: 0.7043 - val_loss: 0.5836 - val_accuracy: 0.7188
# Epoch 2/50
# 41/41 [==============================] - 20s 493ms/step - loss: 0.6010 - accuracy: 0.7264 - val_loss: 0.5836 - val_accuracy: 0.7188
# Epoch 3/50
# 41/41 [==============================] - 20s 493ms/step - loss: 0.5872 - accuracy: 0.7264 - val_loss: 0.5597 - val_accuracy: 0.7244
# Epoch 4/50
# 41/41 [==============================] - 21s 498ms/step - loss: 0.5858 - accuracy: 0.7264 - val_loss: 0.5667 - val_accuracy: 0.7244
# Epoch 5/50
# 41/41 [==============================] - 20s 490ms/step - loss: 0.5828 - accuracy: 0.7264 - val_loss: 0.5658 - val_accuracy: 0.7273
# Epoch 6/50
# 41/41 [==============================] - 20s 492ms/step - loss: 0.5801 - accuracy: 0.7264 - val_loss: 0.5843 - val_accuracy: 0.7244
# Epoch 7/50
# 41/41 [==============================] - 20s 495ms/step - loss: 0.5900 - accuracy: 0.7264 - val_loss: 0.5595 - val_accuracy: 0.7244
# Epoch 8/50
# 41/41 [==============================] - 20s 495ms/step - loss: 0.5834 - accuracy: 0.7264 - val_loss: 0.5931 - val_accuracy: 0.7131
# Epoch 9/50
# 41/41 [==============================] - 21s 500ms/step - loss: 0.5827 - accuracy: 0.7264 - val_loss: 0.5518 - val_accuracy: 0.7358
# Epoch 10/50
# 41/41 [==============================] - 22s 541ms/step - loss: 0.5861 - accuracy: 0.7264 - val_loss: 0.5561 - val_accuracy: 0.7330
# Epoch 11/50
# 41/41 [==============================] - 21s 496ms/step - loss: 0.5859 - accuracy: 0.7264 - val_loss: 0.5685 - val_accuracy: 0.7244
# Epoch 12/50
# 41/41 [==============================] - 21s 497ms/step - loss: 0.5783 - accuracy: 0.7264 - val_loss: 0.5629 - val_accuracy: 0.7244
# Epoch 13/50
# 41/41 [==============================] - 21s 500ms/step - loss: 0.5812 - accuracy: 0.7264 - val_loss: 0.5500 - val_accuracy: 0.7330
# Epoch 14/50
# 41/41 [==============================] - 20s 497ms/step - loss: 0.5833 - accuracy: 0.7264 - val_loss: 0.5530 - val_accuracy: 0.7330
# Epoch 15/50
# 41/41 [==============================] - 21s 500ms/step - loss: 0.5826 - accuracy: 0.7264 - val_loss: 0.5714 - val_accuracy: 0.7159
# Epoch 16/50
# 41/41 [==============================] - 21s 498ms/step - loss: 0.5843 - accuracy: 0.7264 - val_loss: 0.5517 - val_accuracy: 0.7330
# Epoch 17/50
# 41/41 [==============================] - 21s 503ms/step - loss: 0.5760 - accuracy: 0.7264 - val_loss: 0.5696 - val_accuracy: 0.7216
# Epoch 18/50
# 41/41 [==============================] - 21s 499ms/step - loss: 0.5796 - accuracy: 0.7264 - val_loss: 0.5611 - val_accuracy: 0.7301
# Epoch 19/50
# 41/41 [==============================] - 20s 487ms/step - loss: 0.5836 - accuracy: 0.7264 - val_loss: 0.5875 - val_accuracy: 0.7159
# Epoch 20/50
# 41/41 [==============================] - 20s 485ms/step - loss: 0.5788 - accuracy: 0.7264 - val_loss: 0.5638 - val_accuracy: 0.7188
# Epoch 21/50
# 41/41 [==============================] - 20s 488ms/step - loss: 0.5782 - accuracy: 0.7264 - val_loss: 0.5698 - val_accuracy: 0.7330
# Epoch 22/50
# 41/41 [==============================] - 20s 493ms/step - loss: 0.5762 - accuracy: 0.7264 - val_loss: 0.5560 - val_accuracy: 0.7301
# Epoch 23/50
# 41/41 [==============================] - 20s 488ms/step - loss: 0.5826 - accuracy: 0.7264 - val_loss: 0.5999 - val_accuracy: 0.7244
# Epoch 24/50
# 41/41 [==============================] - 20s 488ms/step - loss: 0.5819 - accuracy: 0.7264 - val_loss: 0.5711 - val_accuracy: 0.7216
# Epoch 25/50
# 41/41 [==============================] - 20s 489ms/step - loss: 0.5830 - accuracy: 0.7264 - val_loss: 0.5643 - val_accuracy: 0.7273
# Epoch 26/50
# 41/41 [==============================] - 20s 495ms/step - loss: 0.5772 - accuracy: 0.7264 - val_loss: 0.5547 - val_accuracy: 0.7301
# Epoch 27/50
# 41/41 [==============================] - 20s 489ms/step - loss: 0.5784 - accuracy: 0.7264 - val_loss: 0.5655 - val_accuracy: 0.7188
# Epoch 28/50
# 41/41 [==============================] - 20s 493ms/step - loss: 0.5787 - accuracy: 0.7264 - val_loss: 0.5657 - val_accuracy: 0.7216
# Epoch 29/50
# 41/41 [==============================] - 20s 488ms/step - loss: 0.5726 - accuracy: 0.7264 - val_loss: 0.5598 - val_accuracy: 0.7273
# Epoch 30/50
# 41/41 [==============================] - 20s 490ms/step - loss: 0.5820 - accuracy: 0.7264 - val_loss: 0.5594 - val_accuracy: 0.7216
# Epoch 31/50
# 41/41 [==============================] - 21s 499ms/step - loss: 0.5736 - accuracy: 0.7264 - val_loss: 0.5540 - val_accuracy: 0.7301
# Epoch 32/50
# 41/41 [==============================] - 20s 489ms/step - loss: 0.5722 - accuracy: 0.7264 - val_loss: 0.6060 - val_accuracy: 0.7159
# Epoch 33/50
# 41/41 [==============================] - 20s 493ms/step - loss: 0.5730 - accuracy: 0.7264 - val_loss: 0.5750 - val_accuracy: 0.7244
# Epoch 34/50
# 41/41 [==============================] - 20s 493ms/step - loss: 0.5722 - accuracy: 0.7271 - val_loss: 0.5624 - val_accuracy: 0.7273
# Epoch 35/50
# 41/41 [==============================] - 20s 489ms/step - loss: 0.5741 - accuracy: 0.7264 - val_loss: 0.5635 - val_accuracy: 0.7216
# Epoch 36/50
# 41/41 [==============================] - 20s 493ms/step - loss: 0.5704 - accuracy: 0.7264 - val_loss: 0.5889 - val_accuracy: 0.7301
# Epoch 37/50
# 41/41 [==============================] - 20s 489ms/step - loss: 0.5719 - accuracy: 0.7264 - val_loss: 0.5593 - val_accuracy: 0.7216
# Epoch 38/50
# 41/41 [==============================] - 20s 495ms/step - loss: 0.5738 - accuracy: 0.7271 - val_loss: 0.5613 - val_accuracy: 0.7273
# Epoch 39/50
# 41/41 [==============================] - 22s 545ms/step - loss: 0.5667 - accuracy: 0.7264 - val_loss: 0.5587 - val_accuracy: 0.7188
# Epoch 40/50
# 41/41 [==============================] - 24s 592ms/step - loss: 0.5728 - accuracy: 0.7241 - val_loss: 0.5637 - val_accuracy: 0.7301
# Epoch 41/50
# 41/41 [==============================] - 25s 604ms/step - loss: 0.5772 - accuracy: 0.7264 - val_loss: 0.5452 - val_accuracy: 0.7244
# Epoch 42/50
# 41/41 [==============================] - 26s 628ms/step - loss: 0.5703 - accuracy: 0.7264 - val_loss: 0.5851 - val_accuracy: 0.7273
# Epoch 43/50
# 41/41 [==============================] - 24s 585ms/step - loss: 0.5749 - accuracy: 0.7271 - val_loss: 0.5580 - val_accuracy: 0.7216
# Epoch 44/50
# 41/41 [==============================] - 24s 582ms/step - loss: 0.5709 - accuracy: 0.7279 - val_loss: 0.5780 - val_accuracy: 0.7244
# Epoch 45/50
# 41/41 [==============================] - 23s 569ms/step - loss: 0.5719 - accuracy: 0.7294 - val_loss: 0.6026 - val_accuracy: 0.7216
# Epoch 46/50
# 41/41 [==============================] - 23s 553ms/step - loss: 0.5687 - accuracy: 0.7271 - val_loss: 0.5655 - val_accuracy: 0.7216
# Epoch 47/50
# 41/41 [==============================] - 23s 550ms/step - loss: 0.5667 - accuracy: 0.7279 - val_loss: 0.5689 - val_accuracy: 0.7301
# Epoch 48/50
# 41/41 [==============================] - 22s 543ms/step - loss: 0.5659 - accuracy: 0.7332 - val_loss: 0.5693 - val_accuracy: 0.7273
# Epoch 49/50
# 41/41 [==============================] - 22s 545ms/step - loss: 0.5718 - accuracy: 0.7325 - val_loss: 0.5542 - val_accuracy: 0.7358
# Epoch 50/50
# 41/41 [==============================] - 23s 551ms/step - loss: 0.5658 - accuracy: 0.7279 - val_loss: 0.5520 - val_accuracy: 0.7159
# Found 189 images belonging to 2 classes.
# 6/6 [==============================] - 2s 294ms/step - loss: 0.5496 - accuracy: 0.7302
# Test accuracy: 0.7301587462425232

# %% [markdown]
# # Accuracy using CNN came out to be : 73%

# %% [markdown]
# ## I also tried other architectures too :

# %% [markdown]
# ## Using ResNet:

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model

img_width, img_height = 224, 224
batch_size = 32

base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(img_width, img_height, 3))

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=x)
for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=10  
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary'
)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test accuracy: {test_acc}")

model.save('covid19_resnet_model.h5')
# Out:
# Found 1312 images belonging to 2 classes.
# Found 375 images belonging to 2 classes.
# Epoch 1/10
# 41/41 [==============================] - 53s 1s/step - loss: 0.6355 - accuracy: 0.7119 - val_loss: 0.5851 - val_accuracy: 0.7301
# Epoch 2/10
# 41/41 [==============================] - 52s 1s/step - loss: 0.6122 - accuracy: 0.6982 - val_loss: 0.5827 - val_accuracy: 0.7301
# Epoch 3/10
# 41/41 [==============================] - 55s 1s/step - loss: 0.6134 - accuracy: 0.7134 - val_loss: 0.5949 - val_accuracy: 0.7216
# Epoch 4/10
# 41/41 [==============================] - 55s 1s/step - loss: 0.5974 - accuracy: 0.7256 - val_loss: 0.5792 - val_accuracy: 0.7358
# Epoch 5/10
# 41/41 [==============================] - 56s 1s/step - loss: 0.6170 - accuracy: 0.7241 - val_loss: 0.5886 - val_accuracy: 0.7330
# Epoch 6/10
# 41/41 [==============================] - 54s 1s/step - loss: 0.6034 - accuracy: 0.7271 - val_loss: 0.6014 - val_accuracy: 0.7244
# Epoch 7/10
# 41/41 [==============================] - 57s 1s/step - loss: 0.6175 - accuracy: 0.7142 - val_loss: 0.5866 - val_accuracy: 0.7301
# Epoch 8/10
# 41/41 [==============================] - 52s 1s/step - loss: 0.5921 - accuracy: 0.7279 - val_loss: 0.6014 - val_accuracy: 0.7131
# Epoch 9/10
# 41/41 [==============================] - 51s 1s/step - loss: 0.5927 - accuracy: 0.7264 - val_loss: 0.6028 - val_accuracy: 0.7188
# Epoch 10/10
# 41/41 [==============================] - 54s 1s/step - loss: 0.5977 - accuracy: 0.7218 - val_loss: 0.5849 - val_accuracy: 0.7301
# Found 189 images belonging to 2 classes.
# 6/6 [==============================] - 6s 992ms/step - loss: 0.5937 - accuracy: 0.7249
# Test accuracy: 0.7248677015304565

# %% [markdown]
# ## Using GoogleLeNet:

# %%
from tensorflow.keras.applications import InceptionV3

img_width, img_height = 299, 299  
batch_size = 32

base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(img_width, img_height, 3))

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=x)

for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])


history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=10  # Adjust the number of epochs as needed
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary'
)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test accuracy: {test_acc}")

model.save('covid19_inceptionv3_model.h5')
# Out:
# Found 1312 images belonging to 2 classes.
# Found 375 images belonging to 2 classes.
# Epoch 1/10
# 41/41 [==============================] - 82s 2s/step - loss: 0.7080 - accuracy: 0.7073 - val_loss: 0.5718 - val_accuracy: 0.7358
# Epoch 2/10
# 41/41 [==============================] - 87s 2s/step - loss: 0.6155 - accuracy: 0.7119 - val_loss: 0.5832 - val_accuracy: 0.7301
# Epoch 3/10
# 41/41 [==============================] - 82s 2s/step - loss: 0.5685 - accuracy: 0.7233 - val_loss: 0.5958 - val_accuracy: 0.7273
# Epoch 4/10
# 41/41 [==============================] - 84s 2s/step - loss: 0.5799 - accuracy: 0.7241 - val_loss: 0.5825 - val_accuracy: 0.7159
# Epoch 5/10
# 41/41 [==============================] - 83s 2s/step - loss: 0.5805 - accuracy: 0.7188 - val_loss: 0.5917 - val_accuracy: 0.7074
# Epoch 6/10
# 41/41 [==============================] - 85s 2s/step - loss: 0.5745 - accuracy: 0.7264 - val_loss: 0.5694 - val_accuracy: 0.7273
# Epoch 7/10
# 41/41 [==============================] - 84s 2s/step - loss: 0.5723 - accuracy: 0.7256 - val_loss: 0.6011 - val_accuracy: 0.7244
# Epoch 8/10
# 41/41 [==============================] - 79s 2s/step - loss: 0.5926 - accuracy: 0.7104 - val_loss: 0.6257 - val_accuracy: 0.7244
# Epoch 9/10
# 41/41 [==============================] - 79s 2s/step - loss: 0.5862 - accuracy: 0.7188 - val_loss: 0.5696 - val_accuracy: 0.7358
# Epoch 10/10
# 41/41 [==============================] - 80s 2s/step - loss: 0.5691 - accuracy: 0.7279 - val_loss: 0.5798 - val_accuracy: 0.7244
# Found 189 images belonging to 2 classes.
# 6/6 [==============================] - 9s 1s/step - loss: 0.5918 - accuracy: 0.7302
# Test accuracy: 0.7301587462425232

# %% [markdown]
# # Using Densenet:

# %%
from tensorflow.keras.applications import DenseNet121

img_width, img_height = 224, 224 
batch_size = 32

base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(img_width, img_height, 3))

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=x)

for layer in base_model.layers:
    layer.trainable = False


model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=10 
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary'
)

test_loss, test_acc = model.evaluate(test_generator)
print(f"Test accuracy: {test_acc}")
model.save('covid19_densenet_model.h5')
# Out:
# Found 1312 images belonging to 2 classes.
# Found 375 images belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 1s 0us/step
# Epoch 1/10
# 41/41 [==============================] - 46s 1s/step - loss: 0.7044 - accuracy: 0.6639 - val_loss: 0.5983 - val_accuracy: 0.7216
# Epoch 2/10
# 41/41 [==============================] - 44s 1s/step - loss: 0.5893 - accuracy: 0.7157 - val_loss: 0.6526 - val_accuracy: 0.7273
# Epoch 3/10
# 41/41 [==============================] - 45s 1s/step - loss: 0.5839 - accuracy: 0.7264 - val_loss: 0.5858 - val_accuracy: 0.7244
# Epoch 4/10
# 41/41 [==============================] - 45s 1s/step - loss: 0.5750 - accuracy: 0.7248 - val_loss: 0.5742 - val_accuracy: 0.7216
# Epoch 5/10
# 41/41 [==============================] - 45s 1s/step - loss: 0.5743 - accuracy: 0.7279 - val_loss: 0.6113 - val_accuracy: 0.7244
# Epoch 6/10
# 41/41 [==============================] - 48s 1s/step - loss: 0.5754 - accuracy: 0.7264 - val_loss: 0.5603 - val_accuracy: 0.7386
# Epoch 7/10
# 41/41 [==============================] - 52s 1s/step - loss: 0.5802 - accuracy: 0.7165 - val_loss: 0.5655 - val_accuracy: 0.7216
# Epoch 8/10
# 41/41 [==============================] - 51s 1s/step - loss: 0.5600 - accuracy: 0.7317 - val_loss: 0.5651 - val_accuracy: 0.7358
# Epoch 9/10
# 41/41 [==============================] - 51s 1s/step - loss: 0.5615 - accuracy: 0.7332 - val_loss: 0.5767 - val_accuracy: 0.7216
# Epoch 10/10
# 41/41 [==============================] - 51s 1s/step - loss: 0.5557 - accuracy: 0.7340 - val_loss: 0.5581 - val_accuracy: 0.7216
# Found 189 images belonging to 2 classes.
# 6/6 [==============================] - 6s 915ms/step - loss: 0.5671 - accuracy: 0.7249
# Test accuracy: 0.7248677015304565

# %% [markdown]
# # Result:

# %% [markdown]
# ### <i>After using multiple architectures such as a custom CNN, ResNet, GoogleLeNet, DenseNetfor training the data and best accuracy was achieved by the custom CNN. Best accuracy achieved was 73% by custom CNN</i>
